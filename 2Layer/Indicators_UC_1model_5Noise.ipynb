# %%
# %matplotlib widget

# %%
# Import libraries

import numpy as np
import matplotlib.pyplot as plt
import empymod 
from scipy.constants import mu_0
import pygimli as pg
from pygimli.viewer.mpl import drawModel1D
from sklearn.metrics import root_mean_squared_error
from numpy import linalg as LA
from itertools import product
import plotly.express as px
import pandas as pd
from mpl_toolkits.mplot3d import axes3d
import matplotlib.colors as colors
import random

# %% [markdown]
# # Find Ill-posedness of an inversion problem

# %%
# Create a large range of models

# Define EC of first layer in mS/m
sigma_1 = np.logspace(2,3, 1000)

# EC of second layer with constant ratios
sigma_2 = sigma_1 / 10

# Define a constant product of sigma_1 * thick_1
product_s1t1 = 500

# Define thickness of first layer in meters
thick_1 = product_s1t1 / sigma_1

# Create the models array (EC in S/m)

models =list(np.array([ thick_1, sigma_1/1000, sigma_2/1000]).T)

start_models = list(np.array([ thick_1, sigma_1/1000, sigma_2/1000]).T)  #list(np.array([np.ones_like(sigma_sm), sigma_sm/1000, sigma_sm/1000]).T)

# %% [markdown]
# # Forward Function

# %%
def FDEM(sigmas, thicks, coil_orient=np.array(['H', 'P', 'V']), height=0.15):

    Freq = 9000
    coil_spacing = [2, 4, 8]
    coil_spacing_p = [2.1, 4.1, 8.2]
    
    res_air = 1e6 # air resistivity
    
    sigmas = np.array(sigmas)
    res = np.hstack(([res_air], 1/sigmas))
    
   # print('res: ', res)
    
    depth = np.hstack(([0],-np.cumsum(thicks)))
    
   # print('depth:', depth)
    
    # Define source and receivers geometry
    
    source = [0, 0, -height]
    receivers = [coil_spacing, np.zeros_like(coil_spacing), -height]
    receivers_p = [coil_spacing_p, np.zeros_like(coil_spacing_p), -height]
    
    # Define resistivity model
    #res = np.hstack((res_air, res)) # include air resistivity
    
    # Empty array to store store responses
    OUT = []
    
    # Calculate for horizontal coil orientation
    if any(coil_orient == 'H'):
        # Secondary magnetic field
        H_Hs = empymod.dipole(source, receivers, depth, res, Freq, ab = 66, xdirect = None, 
                              verb=0)*(2j * np.pi * Freq * mu_0) 
        # Primary magnetic field
        H_Hp = empymod.dipole(source, receivers, depth=[], res=[res_air], freqtime = Freq,
                              ab = 66, verb=0)*(2j * np.pi * Freq * mu_0)   
        op = (H_Hs/H_Hp).imag.amp() * 1e3 # Out of Phase
        ip = (H_Hs/H_Hp).real.amp() * 1e3 # In Phase
        OUT.append([op, ip])

    # Calculate for vertical coil orientation
    if any(coil_orient == 'V'):
        # Secondary magnetic field
        V_Hs = empymod.dipole(source, receivers, depth, res, Freq, ab = 55, xdirect = None, 
                              verb=0)*(2j * np.pi * Freq * mu_0) 
        # Primary magnetic field
        V_Hp = empymod.dipole(source, receivers, depth=[], res=[res_air], freqtime = Freq, ab = 55, 
                              verb=0)*(2j * np.pi * Freq * mu_0)
        op = (V_Hs/V_Hp).imag.amp() * 1e3 # Out of Phase
        ip = (V_Hs/V_Hp).real.amp() * 1e3 # In Phase
        OUT.append([op, ip])

    # Calculate for perpendicular coil orientation
    if any(coil_orient == 'P'):
        P_Hs = empymod.dipole(source, receivers, depth, res, Freq, ab = 46, xdirect = None, 
                              verb=0)*(2j * np.pi * Freq * mu_0) 
        P_Hp = empymod.dipole(source, receivers, depth=[], res=[res_air], freqtime= Freq,
                              ab = 66, verb = 0)*(2j * np.pi * Freq * mu_0) 
        op = (P_Hs/P_Hp).imag.amp() * 1e3 # Out of Phase
        ip = (P_Hs/P_Hp).real.amp() * 1e3 # In Phase

        OUT.append([op, ip])

    return np.array(OUT).ravel()

# %% [markdown]
# # Forward modelling class

# %%
class FDEM_1D(pg.frameworks.Modelling):
    """ Class to Initialize the model for Gauss-Newton inversion
    using the quadrature (Q) and in-phase (IP) components of the measurements
    for a n-layered model
    
    Input:

        nlay : number of layers
    """   
    def __init__(self, nlay=3):
        self.nlay = nlay
        mesh = pg.meshtools.createMesh1DBlock(nlay)
        super().__init__()
        self.setMesh(mesh)

    def response(self, par):
        """ Compute response vector for a certain model [mod] 
        par = [thickness_1, thickness_2, ..., thickness_n, sigma_1, sigma_2, ..., sigma_n]
        """
      #  print('model:', par)  
        resp = FDEM(sigmas = par[self.nlay-1:],
                           thicks = par[:self.nlay-1]
                              )
        return resp
    
    def response_mt(self, par, i=0):
        """Multi-threaded forward response."""
        return self.response(par)
        
    def drawModel(self, ax, model):
        pg.viewer.mpl.drawModel1D(ax = ax,
                                  model = model,
                                  plot = 'semilogx',
                                  xlabel = 'Electrical conductivity (S/m)',
                                  )
        ax.set_ylabel('Depth in (m)')

# %% [markdown]
# # Define random starting models

# %%
random.seed(10)
model_start_1 = random.sample(start_models, k=1)[0]
model_start_1
# Out:
# array([1.29832799, 0.3851107 , 0.03851107])

# %%
model_true_1 = random.sample(models, k=1)[0]
model_true_1
# Out:
# array([4.63379665, 0.10790288, 0.01079029])

# %% [markdown]
# # Run Inversion

# %%
# Inversion for 2 Layers

FOP = FDEM_1D(nlay = 2)

data = FOP.response(model_true_1)
data *=  1 + 0.05 *np.random.rand(len(data))

transThk = pg.trans.TransLogLU(0.01,5.1)
transSig = pg.trans.TransLogLU(1/1000,2000/1000)

FOP.region(0).setTransModel(transThk)
FOP.region(1).setTransModel(transSig)

inv = pg.Inversion()
inv.setForwardOperator(FOP)
J = inv.fop.jacobian()

rel_err = np.ones_like(data)*1e-1
model_inv = inv.run(data, rel_err, verbose=False, startModel=model_start_1, lam=0, )

model_inv
# Out:
# 3 [3.1537981777257227, 0.11154623890856101, 0.044211500394821246]

# %%
fig, ax = plt.subplots(1,3, figsize=(12,4))

# Plot Jacobian
c = ax[0].imshow(np.array(J).T)
fig.colorbar(c, shrink=0.2, ax=ax[0])
xticks = ['H2 Q', 'H4 Q', 'H8 Q', 'H2 IP', 'H4 IP', 'H8 IP', 'V2 Q', 'V4 Q', 'V8 Q',
          'V2 IP', 'V4 IP', 'V8 IP', 'P2 Q', 'P4 Q', 'P8 Q', 'P2 IP', 'P4 IP', 'P8 IP' ]
yticks = ['$h_1$', '$\sigma_1$', '$\sigma_2$' ]
ax[0].set_xticks(range(len(data)), labels=xticks, rotation = 90)
ax[0].set_yticks(range(len(model_true_1)), labels=yticks)
ax[0].set_title('Rank of J: ' + str( np.linalg.matrix_rank(J)) +' - Condition number: %.2f' %np.linalg.cond(J) )

# Calculate Hessian
J = np.array(J)
JTJ = np.matmul(J.T,J)
# Plot Hessian
c = ax[1].imshow(JTJ, cmap='jet') 
fig.colorbar(c, ax=ax[1], shrink=0.5)
ax[1].set_title('Hessian matrix')

# Compute eigenvalues
eigenvalues, eigenvectors = LA.eigh(JTJ)  # More stable for symmetric matrices

# Plot eigenvalues

xticks = ['h1', 's1', 's2']

ax[2].set_xticks(range(3), labels=xticks, rotation = 90)
ax[2].semilogy(eigenvalues, 'o-', label="Eigenvalues")
#ax[2].axhline(y=0, color='r', linestyle='--', label="Zero Line")
ax[2].set_xlabel("Parameter")
ax[2].set_ylabel("Eigenvalue")
ax[2].legend()

# Print condition number
condition_number = np.max(eigenvalues) / np.min(eigenvalues)
ax[2].set_title(f"Hessian Condition Number: {condition_number:.2e}")

plt.tight_layout()
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %% [markdown]
# # Check with 10 different starting models

# %%
random.seed(10)
model_start_10 = random.sample(start_models, k=10)
model_start_10
# Out:
# [array([1.29832799, 0.3851107 , 0.03851107]),
#  array([4.63379665, 0.10790288, 0.01079029]),
#  array([1.81773498, 0.2750676 , 0.02750676]),
#  array([1.60131035, 0.31224428, 0.03122443]),
#  array([1.28049655, 0.39047352, 0.03904735]),
#  array([4.8300874 , 0.1035178 , 0.01035178]),
#  array([3.07438883, 0.16263395, 0.0162634 ]),
#  array([1.6807245 , 0.29749075, 0.02974908]),
#  array([0.7347459 , 0.68050737, 0.06805074]),
#  array([1.56843491, 0.31878913, 0.03187891])]

# %%
# Run inversions

J_s = []

for sm in model_start_10:
    # Inversion for 2 Layers

    FOP = FDEM_1D(nlay = 2)
    
    data = FOP.response(model_true_1)
    data *=  1 + 0.05 *np.random.rand(len(data))
    
    transThk = pg.trans.TransLogLU(0.01,5.1)
    transSig = pg.trans.TransLogLU(1/1000,2000/1000)
    
    FOP.region(0).setTransModel(transThk)
    FOP.region(1).setTransModel(transSig)
    
    inv = pg.Inversion()
    inv.setForwardOperator(FOP)
    J = inv.fop.jacobian()
    
    rel_err = np.ones_like(data)*1e-1
    model_inv = inv.run(data, rel_err, verbose=False, startModel=sm, lam=0, )
    J_s.append(np.array(J))

# %%
# Calculate rank, Condition number, hessians and eigenvalues

rank_J = []
CN_J = []
CN_H = []
eigenvalues_H = []
#ev_h1 = []
#ev_s1 = []
#ev_s2 = []
condition = []

for j in J_s:
    rank_J.append(np.linalg.matrix_rank(j))
    CN_J.append(np.linalg.cond(j))
    H = np.matmul(j.T, j)
    eigenvalues, eigenvectors = LA.eigh(H)
    eigenvalues_H.append(eigenvalues)
    CN_H.append( np.max(eigenvalues) / np.min(eigenvalues))
    
    if np.all(np.array(eigenvalues) > 0):
        condition.append(1)
        print("The Hessian is positive definite → Likely a global minimum.")
    elif np.any(np.array(eigenvalues) < 0):
        condition.append(-1)
        print("The Hessian has negative eigenvalues → Could be a saddle point or local maximum.")
    else:
        condition.append(0)
        print("The Hessian has near-zero eigenvalues → Possible flat directions (ill-conditioning).")
# Out:
# The Hessian is positive definite → Likely a global minimum.
# The Hessian is positive definite → Likely a global minimum.
# The Hessian is positive definite → Likely a global minimum.
# The Hessian is positive definite → Likely a global minimum.
# The Hessian is positive definite → Likely a global minimum.
# The Hessian is positive definite → Likely a global minimum.
# The Hessian is positive definite → Likely a global minimum.
# The Hessian is positive definite → Likely a global minimum.
# The Hessian is positive definite → Likely a global minimum.
# The Hessian is positive definite → Likely a global minimum.

# %%
df_10 = pd.DataFrame(data= np.array([np.array(model_start_10)[:,0], np.array(model_start_10)[:,1], np.array(model_start_10)[:,2], rank_J,
                                 CN_J, CN_H, condition]).T, columns = ['h_1', 'sig_1', 'sig_2', 'rank_J', 'CN_J', 'CN_H', 'cond'])

# %%
df_10.style.highlight_max(subset=pd.IndexSlice[:, ['cond']], color='green')
# Out:
# <style type="text/css">
# #T_e9554_row0_col6, #T_e9554_row1_col6, #T_e9554_row2_col6, #T_e9554_row3_col6, #T_e9554_row4_col6, #T_e9554_row5_col6, #T_e9554_row6_col6, #T_e9554_row7_col6, #T_e9554_row8_col6, #T_e9554_row9_col6 {
#   background-color: green;
# }
# </style>
# <table id="T_e9554">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_e9554_level0_col0" class="col_heading level0 col0" >h_1</th>
#       <th id="T_e9554_level0_col1" class="col_heading level0 col1" >sig_1</th>
#       <th id="T_e9554_level0_col2" class="col_heading level0 col2" >sig_2</th>
#       <th id="T_e9554_level0_col3" class="col_heading level0 col3" >rank_J</th>
#       <th id="T_e9554_level0_col4" class="col_heading level0 col4" >CN_J</th>
#       <th id="T_e9554_level0_col5" class="col_heading level0 col5" >CN_H</th>
#       <th id="T_e9554_level0_col6" class="col_heading level0 col6" >cond</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_e9554_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_e9554_row0_col0" class="data row0 col0" >1.298328</td>
#       <td id="T_e9554_row0_col1" class="data row0 col1" >0.385111</td>
#       <td id="T_e9554_row0_col2" class="data row0 col2" >0.038511</td>
#       <td id="T_e9554_row0_col3" class="data row0 col3" >3.000000</td>
#       <td id="T_e9554_row0_col4" class="data row0 col4" >1068.434425</td>
#       <td id="T_e9554_row0_col5" class="data row0 col5" >1141552.120332</td>
#       <td id="T_e9554_row0_col6" class="data row0 col6" >1.000000</td>
#     </tr>
#     <tr>
#       <th id="T_e9554_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_e9554_row1_col0" class="data row1 col0" >4.633797</td>
#       <td id="T_e9554_row1_col1" class="data row1 col1" >0.107903</td>
#       <td id="T_e9554_row1_col2" class="data row1 col2" >0.010790</td>
#       <td id="T_e9554_row1_col3" class="data row1 col3" >3.000000</td>
#       <td id="T_e9554_row1_col4" class="data row1 col4" >833.683954</td>
#       <td id="T_e9554_row1_col5" class="data row1 col5" >695028.935341</td>
#       <td id="T_e9554_row1_col6" class="data row1 col6" >1.000000</td>
#     </tr>
#     <tr>
#       <th id="T_e9554_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_e9554_row2_col0" class="data row2 col0" >1.817735</td>
#       <td id="T_e9554_row2_col1" class="data row2 col1" >0.275068</td>
#       <td id="T_e9554_row2_col2" class="data row2 col2" >0.027507</td>
#       <td id="T_e9554_row2_col3" class="data row2 col3" >3.000000</td>
#       <td id="T_e9554_row2_col4" class="data row2 col4" >822.639688</td>
#       <td id="T_e9554_row2_col5" class="data row2 col5" >676736.055851</td>
#       <td id="T_e9554_row2_col6" class="data row2 col6" >1.000000</td>
#     </tr>
#     <tr>
#       <th id="T_e9554_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_e9554_row3_col0" class="data row3 col0" >1.601310</td>
#       <td id="T_e9554_row3_col1" class="data row3 col1" >0.312244</td>
#       <td id="T_e9554_row3_col2" class="data row3 col2" >0.031224</td>
#       <td id="T_e9554_row3_col3" class="data row3 col3" >3.000000</td>
#       <td id="T_e9554_row3_col4" class="data row3 col4" >623.047337</td>
#       <td id="T_e9554_row3_col5" class="data row3 col5" >388187.984368</td>
#       <td id="T_e9554_row3_col6" class="data row3 col6" >1.000000</td>
#     </tr>
#     <tr>
#       <th id="T_e9554_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_e9554_row4_col0" class="data row4 col0" >1.280497</td>
#       <td id="T_e9554_row4_col1" class="data row4 col1" >0.390474</td>
#       <td id="T_e9554_row4_col2" class="data row4 col2" >0.039047</td>
#       <td id="T_e9554_row4_col3" class="data row4 col3" >3.000000</td>
#       <td id="T_e9554_row4_col4" class="data row4 col4" >289.579844</td>
#       <td id="T_e9554_row4_col5" class="data row4 col5" >83856.486263</td>
#       <td id="T_e9554_row4_col6" class="data row4 col6" >1.000000</td>
#     </tr>
#     <tr>
#       <th id="T_e9554_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_e9554_row5_col0" class="data row5 col0" >4.830087</td>
#       <td id="T_e9554_row5_col1" class="data row5 col1" >0.103518</td>
#       <td id="T_e9554_row5_col2" class="data row5 col2" >0.010352</td>
#       <td id="T_e9554_row5_col3" class="data row5 col3" >3.000000</td>
#       <td id="T_e9554_row5_col4" class="data row5 col4" >933.070257</td>
#       <td id="T_e9554_row5_col5" class="data row5 col5" >870620.104114</td>
#       <td id="T_e9554_row5_col6" class="data row5 col6" >1.000000</td>
#     </tr>
#     <tr>
#       <th id="T_e9554_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_e9554_row6_col0" class="data row6 col0" >3.074389</td>
#       <td id="T_e9554_row6_col1" class="data row6 col1" >0.162634</td>
#       <td id="T_e9554_row6_col2" class="data row6 col2" >0.016263</td>
#       <td id="T_e9554_row6_col3" class="data row6 col3" >3.000000</td>
#       <td id="T_e9554_row6_col4" class="data row6 col4" >218.350285</td>
#       <td id="T_e9554_row6_col5" class="data row6 col5" >47676.847169</td>
#       <td id="T_e9554_row6_col6" class="data row6 col6" >1.000000</td>
#     </tr>
#     <tr>
#       <th id="T_e9554_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_e9554_row7_col0" class="data row7 col0" >1.680725</td>
#       <td id="T_e9554_row7_col1" class="data row7 col1" >0.297491</td>
#       <td id="T_e9554_row7_col2" class="data row7 col2" >0.029749</td>
#       <td id="T_e9554_row7_col3" class="data row7 col3" >3.000000</td>
#       <td id="T_e9554_row7_col4" class="data row7 col4" >662.135524</td>
#       <td id="T_e9554_row7_col5" class="data row7 col5" >438423.451828</td>
#       <td id="T_e9554_row7_col6" class="data row7 col6" >1.000000</td>
#     </tr>
#     <tr>
#       <th id="T_e9554_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_e9554_row8_col0" class="data row8 col0" >0.734746</td>
#       <td id="T_e9554_row8_col1" class="data row8 col1" >0.680507</td>
#       <td id="T_e9554_row8_col2" class="data row8 col2" >0.068051</td>
#       <td id="T_e9554_row8_col3" class="data row8 col3" >3.000000</td>
#       <td id="T_e9554_row8_col4" class="data row8 col4" >866.233915</td>
#       <td id="T_e9554_row8_col5" class="data row8 col5" >750361.196219</td>
#       <td id="T_e9554_row8_col6" class="data row8 col6" >1.000000</td>
#     </tr>
#     <tr>
#       <th id="T_e9554_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_e9554_row9_col0" class="data row9 col0" >1.568435</td>
#       <td id="T_e9554_row9_col1" class="data row9 col1" >0.318789</td>
#       <td id="T_e9554_row9_col2" class="data row9 col2" >0.031879</td>
#       <td id="T_e9554_row9_col3" class="data row9 col3" >3.000000</td>
#       <td id="T_e9554_row9_col4" class="data row9 col4" >820.900236</td>
#       <td id="T_e9554_row9_col5" class="data row9 col5" >673877.197679</td>
#       <td id="T_e9554_row9_col6" class="data row9 col6" >1.000000</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# # Check with 100 different starting models

# %%
random.seed(10)
model_start_100 = random.sample(start_models, k=100)

# Run inversions

J_s = []
model_test = []

for sm in model_start_100:
    # Inversion for 2 Layers
    if (sm == model_true_1).any():
        pass
    else:
        model_test.append(sm)
        FOP = FDEM_1D(nlay = 2)
        
        data = FOP.response(model_true_1)
        data *=  1 + 0.05 *np.random.rand(len(data))
        
        transThk = pg.trans.TransLogLU(0.01,5.1)
        transSig = pg.trans.TransLogLU(1/1000,2000/1000)
        
        FOP.region(0).setTransModel(transThk)
        FOP.region(1).setTransModel(transSig)
        
        inv = pg.Inversion()
        inv.setForwardOperator(FOP)
        J = inv.fop.jacobian()
        
        rel_err = np.ones_like(data)*1e-1
        model_inv = inv.run(data, rel_err, verbose=False, startModel=sm, lam=0, )
        J_s.append(np.array(J))

# Calculate rank, Condition number, hessians and eigenvalues

rank_J = []
CN_J = []
CN_H = []
eigenvalues_H = []
#ev_h1 = []
#ev_s1 = []
#ev_s2 = []
condition = []

for j in J_s:
    rank_J.append(np.linalg.matrix_rank(j))
    CN_J.append(np.linalg.cond(j))
    H = np.matmul(j.T, j)
    eigenvalues, eigenvectors = LA.eigh(H)
    eigenvalues_H.append(eigenvalues)
    CN_H.append( np.max(eigenvalues) / np.min(eigenvalues))
    
    if np.all(np.array(eigenvalues) > 0):
        condition.append(1)
       # print("The Hessian is positive definite → Likely a global minimum.")
    elif np.any(np.array(eigenvalues) < 0):
        condition.append(-1)
       # print("The Hessian has negative eigenvalues → Could be a saddle point or local maximum.")
    else:
        condition.append(0)
       # print("The Hessian has near-zero eigenvalues → Possible flat directions (ill-conditioning).")

# %%
df_100 = pd.DataFrame(data= np.array([np.array(model_test)[:,0], np.array(model_test)[:,1], np.array(model_test)[:,2], rank_J,
                                 CN_J, CN_H, condition]).T, columns = ['h_1', 'sig_1', 'sig_2', 'rank_J', 'CN_J', 'CN_H', 'cond'])

df_100.style.background_gradient(subset=pd.IndexSlice[:, ['rank_J', 'CN_J', 'CN_H','cond']])
# Out:
# <style type="text/css">
# #T_5b80a_row0_col3, #T_5b80a_row0_col5, #T_5b80a_row0_col6, #T_5b80a_row1_col3, #T_5b80a_row1_col4, #T_5b80a_row1_col5, #T_5b80a_row1_col6, #T_5b80a_row2_col3, #T_5b80a_row2_col4, #T_5b80a_row2_col5, #T_5b80a_row2_col6, #T_5b80a_row3_col3, #T_5b80a_row3_col5, #T_5b80a_row3_col6, #T_5b80a_row4_col3, #T_5b80a_row4_col4, #T_5b80a_row4_col5, #T_5b80a_row4_col6, #T_5b80a_row5_col3, #T_5b80a_row5_col4, #T_5b80a_row5_col5, #T_5b80a_row5_col6, #T_5b80a_row6_col3, #T_5b80a_row6_col4, #T_5b80a_row6_col5, #T_5b80a_row6_col6, #T_5b80a_row7_col3, #T_5b80a_row7_col4, #T_5b80a_row7_col5, #T_5b80a_row7_col6, #T_5b80a_row8_col3, #T_5b80a_row8_col4, #T_5b80a_row8_col5, #T_5b80a_row8_col6, #T_5b80a_row9_col3, #T_5b80a_row9_col4, #T_5b80a_row9_col5, #T_5b80a_row9_col6, #T_5b80a_row10_col3, #T_5b80a_row10_col4, #T_5b80a_row10_col5, #T_5b80a_row10_col6, #T_5b80a_row11_col3, #T_5b80a_row11_col4, #T_5b80a_row11_col5, #T_5b80a_row11_col6, #T_5b80a_row12_col3, #T_5b80a_row12_col4, #T_5b80a_row12_col5, #T_5b80a_row12_col6, #T_5b80a_row13_col3, #T_5b80a_row13_col4, #T_5b80a_row13_col5, #T_5b80a_row13_col6, #T_5b80a_row14_col3, #T_5b80a_row14_col4, #T_5b80a_row14_col5, #T_5b80a_row14_col6, #T_5b80a_row15_col3, #T_5b80a_row15_col4, #T_5b80a_row15_col5, #T_5b80a_row15_col6, #T_5b80a_row16_col3, #T_5b80a_row16_col4, #T_5b80a_row16_col5, #T_5b80a_row16_col6, #T_5b80a_row17_col3, #T_5b80a_row17_col4, #T_5b80a_row17_col5, #T_5b80a_row17_col6, #T_5b80a_row18_col3, #T_5b80a_row18_col4, #T_5b80a_row18_col5, #T_5b80a_row18_col6, #T_5b80a_row19_col3, #T_5b80a_row19_col4, #T_5b80a_row19_col5, #T_5b80a_row19_col6, #T_5b80a_row20_col3, #T_5b80a_row20_col5, #T_5b80a_row20_col6, #T_5b80a_row21_col3, #T_5b80a_row21_col4, #T_5b80a_row21_col5, #T_5b80a_row21_col6, #T_5b80a_row22_col3, #T_5b80a_row22_col4, #T_5b80a_row22_col5, #T_5b80a_row22_col6, #T_5b80a_row23_col3, #T_5b80a_row23_col4, #T_5b80a_row23_col5, #T_5b80a_row23_col6, #T_5b80a_row24_col3, #T_5b80a_row24_col4, #T_5b80a_row24_col5, #T_5b80a_row24_col6, #T_5b80a_row25_col3, #T_5b80a_row25_col4, #T_5b80a_row25_col5, #T_5b80a_row25_col6, #T_5b80a_row26_col3, #T_5b80a_row26_col4, #T_5b80a_row26_col5, #T_5b80a_row26_col6, #T_5b80a_row27_col3, #T_5b80a_row27_col4, #T_5b80a_row27_col5, #T_5b80a_row27_col6, #T_5b80a_row28_col3, #T_5b80a_row28_col4, #T_5b80a_row28_col5, #T_5b80a_row28_col6, #T_5b80a_row29_col3, #T_5b80a_row29_col4, #T_5b80a_row29_col5, #T_5b80a_row29_col6, #T_5b80a_row30_col3, #T_5b80a_row30_col4, #T_5b80a_row30_col5, #T_5b80a_row30_col6, #T_5b80a_row31_col3, #T_5b80a_row31_col4, #T_5b80a_row31_col5, #T_5b80a_row31_col6, #T_5b80a_row32_col3, #T_5b80a_row32_col4, #T_5b80a_row32_col5, #T_5b80a_row32_col6, #T_5b80a_row33_col3, #T_5b80a_row33_col4, #T_5b80a_row33_col5, #T_5b80a_row33_col6, #T_5b80a_row34_col3, #T_5b80a_row34_col4, #T_5b80a_row34_col5, #T_5b80a_row34_col6, #T_5b80a_row35_col3, #T_5b80a_row35_col4, #T_5b80a_row35_col5, #T_5b80a_row35_col6, #T_5b80a_row36_col3, #T_5b80a_row36_col4, #T_5b80a_row36_col5, #T_5b80a_row36_col6, #T_5b80a_row37_col3, #T_5b80a_row37_col4, #T_5b80a_row37_col5, #T_5b80a_row37_col6, #T_5b80a_row38_col3, #T_5b80a_row38_col4, #T_5b80a_row38_col5, #T_5b80a_row38_col6, #T_5b80a_row39_col3, #T_5b80a_row39_col4, #T_5b80a_row39_col5, #T_5b80a_row39_col6, #T_5b80a_row40_col3, #T_5b80a_row40_col6, #T_5b80a_row41_col3, #T_5b80a_row41_col4, #T_5b80a_row41_col5, #T_5b80a_row41_col6, #T_5b80a_row42_col3, #T_5b80a_row42_col4, #T_5b80a_row42_col5, #T_5b80a_row42_col6, #T_5b80a_row43_col3, #T_5b80a_row43_col5, #T_5b80a_row43_col6, #T_5b80a_row44_col3, #T_5b80a_row44_col4, #T_5b80a_row44_col5, #T_5b80a_row44_col6, #T_5b80a_row45_col3, #T_5b80a_row45_col4, #T_5b80a_row45_col5, #T_5b80a_row45_col6, #T_5b80a_row46_col3, #T_5b80a_row46_col4, #T_5b80a_row46_col5, #T_5b80a_row46_col6, #T_5b80a_row47_col3, #T_5b80a_row47_col4, #T_5b80a_row47_col5, #T_5b80a_row47_col6, #T_5b80a_row48_col3, #T_5b80a_row48_col5, #T_5b80a_row48_col6, #T_5b80a_row49_col3, #T_5b80a_row49_col4, #T_5b80a_row49_col5, #T_5b8 ...

# %%
df_100[df_100['cond']==0].style.highlight_min(subset=pd.IndexSlice[:, ['cond']], color='red')
# Out:
# <style type="text/css">
# </style>
# <table id="T_3d393">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_3d393_level0_col0" class="col_heading level0 col0" >h_1</th>
#       <th id="T_3d393_level0_col1" class="col_heading level0 col1" >sig_1</th>
#       <th id="T_3d393_level0_col2" class="col_heading level0 col2" >sig_2</th>
#       <th id="T_3d393_level0_col3" class="col_heading level0 col3" >rank_J</th>
#       <th id="T_3d393_level0_col4" class="col_heading level0 col4" >CN_J</th>
#       <th id="T_3d393_level0_col5" class="col_heading level0 col5" >CN_H</th>
#       <th id="T_3d393_level0_col6" class="col_heading level0 col6" >cond</th>
#     </tr>
#   </thead>
#   <tbody>
#   </tbody>
# </table>

# %% [markdown]
# # Check with 1000 starting models

# %%
# Run inversions

J_s = []
models_test = []

for sm in start_models:
    # Inversion for 2 Layers
    if (sm == model_true_1).any():
        pass
    else:
        models_test.append(sm)
        FOP = FDEM_1D(nlay = 2)
        
        data = FOP.response(model_true_1)
        data *=  1 + 0.05 *np.random.rand(len(data))
        
        transThk = pg.trans.TransLogLU(0.01,5.1)
        transSig = pg.trans.TransLogLU(1/1000,2000/1000)
        
        FOP.region(0).setTransModel(transThk)
        FOP.region(1).setTransModel(transSig)
        
        inv = pg.Inversion()
        inv.setForwardOperator(FOP)
        J = inv.fop.jacobian()
        
        rel_err = np.ones_like(data)*1e-1
        model_inv = inv.run(data, rel_err, verbose=False, startModel=sm, lam=0, )
        J_s.append(np.array(J))

# Calculate rank, Condition number, hessians and eigenvalues

rank_J = []
CN_J = []
CN_H = []
eigenvalues_H = []
#ev_h1 = []
#ev_s1 = []
#ev_s2 = []
condition = []

for j in J_s:
    rank_J.append(np.linalg.matrix_rank(j))
    CN_J.append(np.linalg.cond(j))
    H = np.matmul(j.T, j)
    eigenvalues, eigenvectors = LA.eigh(H)
    eigenvalues_H.append(eigenvalues)
    CN_H.append( np.max(eigenvalues) / np.min(eigenvalues))
    
    if np.all(np.array(eigenvalues) > 0):
        condition.append(1)
       # print("The Hessian is positive definite → Likely a global minimum.")
    elif np.any(np.array(eigenvalues) < 0):
        condition.append(-1)
       # print("The Hessian has negative eigenvalues → Could be a saddle point or local maximum.")
    else:
        condition.append(0)
       # print("The Hessian has near-zero eigenvalues → Possible flat directions (ill-conditioning).")

# %%
df_1000 = pd.DataFrame(data= np.array([np.array(models_test)[:,0], np.array(models_test)[:,1], np.array(models_test)[:,2], rank_J,
                                 CN_J, CN_H, condition]).T, columns = ['h_1', 'sig_1', 'sig_2', 'rank_J', 'CN_J', 'CN_H', 'cond'])

df_1000.style.background_gradient(subset=pd.IndexSlice[:, ['rank_J', 'CN_J', 'CN_H','cond']])
# Out:
# <style type="text/css">
# #T_7c603_row0_col3, #T_7c603_row0_col6, #T_7c603_row1_col3, #T_7c603_row1_col4, #T_7c603_row1_col5, #T_7c603_row1_col6, #T_7c603_row2_col3, #T_7c603_row2_col4, #T_7c603_row2_col5, #T_7c603_row2_col6, #T_7c603_row3_col3, #T_7c603_row3_col4, #T_7c603_row3_col5, #T_7c603_row3_col6, #T_7c603_row4_col3, #T_7c603_row4_col4, #T_7c603_row4_col5, #T_7c603_row4_col6, #T_7c603_row5_col3, #T_7c603_row5_col4, #T_7c603_row5_col5, #T_7c603_row5_col6, #T_7c603_row6_col3, #T_7c603_row6_col4, #T_7c603_row6_col5, #T_7c603_row6_col6, #T_7c603_row7_col3, #T_7c603_row7_col4, #T_7c603_row7_col5, #T_7c603_row7_col6, #T_7c603_row8_col3, #T_7c603_row8_col4, #T_7c603_row8_col5, #T_7c603_row8_col6, #T_7c603_row9_col3, #T_7c603_row9_col4, #T_7c603_row9_col5, #T_7c603_row9_col6, #T_7c603_row10_col3, #T_7c603_row10_col4, #T_7c603_row10_col5, #T_7c603_row10_col6, #T_7c603_row11_col3, #T_7c603_row11_col4, #T_7c603_row11_col5, #T_7c603_row11_col6, #T_7c603_row12_col3, #T_7c603_row12_col4, #T_7c603_row12_col5, #T_7c603_row12_col6, #T_7c603_row13_col3, #T_7c603_row13_col4, #T_7c603_row13_col5, #T_7c603_row13_col6, #T_7c603_row14_col3, #T_7c603_row14_col4, #T_7c603_row14_col5, #T_7c603_row14_col6, #T_7c603_row15_col3, #T_7c603_row15_col4, #T_7c603_row15_col5, #T_7c603_row15_col6, #T_7c603_row16_col3, #T_7c603_row16_col4, #T_7c603_row16_col5, #T_7c603_row16_col6, #T_7c603_row17_col3, #T_7c603_row17_col4, #T_7c603_row17_col5, #T_7c603_row17_col6, #T_7c603_row18_col3, #T_7c603_row18_col4, #T_7c603_row18_col5, #T_7c603_row18_col6, #T_7c603_row19_col3, #T_7c603_row19_col4, #T_7c603_row19_col5, #T_7c603_row19_col6, #T_7c603_row20_col3, #T_7c603_row20_col4, #T_7c603_row20_col5, #T_7c603_row20_col6, #T_7c603_row21_col3, #T_7c603_row21_col4, #T_7c603_row21_col5, #T_7c603_row21_col6, #T_7c603_row22_col3, #T_7c603_row22_col4, #T_7c603_row22_col5, #T_7c603_row22_col6, #T_7c603_row23_col3, #T_7c603_row23_col4, #T_7c603_row23_col5, #T_7c603_row23_col6, #T_7c603_row24_col3, #T_7c603_row24_col4, #T_7c603_row24_col5, #T_7c603_row24_col6, #T_7c603_row25_col3, #T_7c603_row25_col4, #T_7c603_row25_col5, #T_7c603_row25_col6, #T_7c603_row26_col3, #T_7c603_row26_col4, #T_7c603_row26_col5, #T_7c603_row26_col6, #T_7c603_row27_col3, #T_7c603_row27_col4, #T_7c603_row27_col5, #T_7c603_row27_col6, #T_7c603_row28_col3, #T_7c603_row28_col4, #T_7c603_row28_col5, #T_7c603_row28_col6, #T_7c603_row29_col3, #T_7c603_row29_col4, #T_7c603_row29_col5, #T_7c603_row29_col6, #T_7c603_row30_col3, #T_7c603_row30_col4, #T_7c603_row30_col5, #T_7c603_row30_col6, #T_7c603_row31_col3, #T_7c603_row31_col4, #T_7c603_row31_col5, #T_7c603_row31_col6, #T_7c603_row32_col3, #T_7c603_row32_col4, #T_7c603_row32_col5, #T_7c603_row32_col6, #T_7c603_row33_col3, #T_7c603_row33_col4, #T_7c603_row33_col5, #T_7c603_row33_col6, #T_7c603_row34_col3, #T_7c603_row34_col4, #T_7c603_row34_col5, #T_7c603_row34_col6, #T_7c603_row35_col3, #T_7c603_row35_col4, #T_7c603_row35_col5, #T_7c603_row35_col6, #T_7c603_row36_col3, #T_7c603_row36_col4, #T_7c603_row36_col5, #T_7c603_row36_col6, #T_7c603_row37_col3, #T_7c603_row37_col4, #T_7c603_row37_col5, #T_7c603_row37_col6, #T_7c603_row38_col3, #T_7c603_row38_col4, #T_7c603_row38_col5, #T_7c603_row38_col6, #T_7c603_row39_col3, #T_7c603_row39_col4, #T_7c603_row39_col5, #T_7c603_row39_col6, #T_7c603_row40_col3, #T_7c603_row40_col4, #T_7c603_row40_col5, #T_7c603_row40_col6, #T_7c603_row41_col3, #T_7c603_row41_col4, #T_7c603_row41_col5, #T_7c603_row41_col6, #T_7c603_row42_col3, #T_7c603_row42_col4, #T_7c603_row42_col5, #T_7c603_row42_col6, #T_7c603_row43_col3, #T_7c603_row43_col4, #T_7c603_row43_col5, #T_7c603_row43_col6, #T_7c603_row44_col3, #T_7c603_row44_col4, #T_7c603_row44_col5, #T_7c603_row44_col6, #T_7c603_row45_col3, #T_7c603_row45_col4, #T_7c603_row45_col5, #T_7c603_row45_col6, #T_7c603_row46_col3, #T_7c603_row46_col4, #T_7c603_row46_col5, #T_7c603_row46_col6, #T_7c603_row47_col3, #T_7c603_row47_col4, #T_7c603_row47_col5, #T_7c603_row47_col6, #T_7c603_row48_col3, #T_7c603_row48_col4, #T_7c6 ...

# %%
df_1000[df_1000['cond']==0].style.highlight_min(subset=pd.IndexSlice[:, ['cond']], color='red')
# Out:
# <style type="text/css">
# </style>
# <table id="T_830ad">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_830ad_level0_col0" class="col_heading level0 col0" >h_1</th>
#       <th id="T_830ad_level0_col1" class="col_heading level0 col1" >sig_1</th>
#       <th id="T_830ad_level0_col2" class="col_heading level0 col2" >sig_2</th>
#       <th id="T_830ad_level0_col3" class="col_heading level0 col3" >rank_J</th>
#       <th id="T_830ad_level0_col4" class="col_heading level0 col4" >CN_J</th>
#       <th id="T_830ad_level0_col5" class="col_heading level0 col5" >CN_H</th>
#       <th id="T_830ad_level0_col6" class="col_heading level0 col6" >cond</th>
#     </tr>
#   </thead>
#   <tbody>
#   </tbody>
# </table>

# %%
fig, ax = plt.subplots(2,2, figsize=(10,6))

hist, bins, _ = ax[0,0].hist(df_10['CN_J'], bins=8, alpha=0.5, label = '10 samples SM')
logbins = np.logspace(np.log10(bins[0]),np.log10(bins[-1]),len(bins))
ax[1,0].hist(df_10['CN_J'], alpha=0.5, bins=logbins, label = '10 samples SM')

hist, bins, _ = ax[0,0].hist(df_100['CN_J'], bins=8, alpha=0.5, label = '100 samples SM')
logbins = np.logspace(np.log10(bins[0]),np.log10(bins[-1]),len(bins))
ax[1,0].hist(df_100['CN_J'], alpha=0.5, bins=logbins, label = '100 samples SM')

hist, bins, _ = ax[0,0].hist(df_1000['CN_J'], bins=8, alpha=0.5, label = '1000 samples SM', log=True)
logbins = np.logspace(np.log10(bins[0]),np.log10(bins[-1]),len(bins))
ax[1,0].hist(df_1000['CN_J'], alpha=0.5, bins=logbins, label = '1000 samples SM', log=True)

ax[0,0].legend()
ax[1,0].set_xscale('log')
ax[0,0].set_title('Condition Number of Jacobian')

hist, bins, _ = ax[0,1].hist(df_10['CN_H'], bins=8, alpha=0.5, label = '10 samples SM')
logbins = np.logspace(np.log10(bins[0]),np.log10(bins[-1]),len(bins))
ax[1,1].hist(df_10['CN_H'], alpha=0.5, bins=logbins, label = '10 samples SM')

hist, bins, _ = ax[0,1].hist(df_100['CN_H'], bins=8, alpha=0.5, label = '100 samples SM')
logbins = np.logspace(np.log10(bins[0]),np.log10(bins[-1]),len(bins))
ax[1,1].hist(df_100['CN_H'], alpha=0.5, bins=logbins, label = '100 samples SM')

hist, bins, _ = ax[0,1].hist(df_1000['CN_H'], bins=8, alpha=0.5, label = '1000 samples SM', log=True)
logbins = np.logspace(np.log10(bins[0]),np.log10(bins[-1]),len(bins))
ax[1,1].hist(df_1000['CN_H'], alpha=0.5, bins=logbins, label = '1000 samples SM', log=True)

ax[0,1].legend()
ax[1,1].set_xscale('log')
ax[0,1].set_title('Condition Number of Hessian')
fig.suptitle('Noise 5 %')
# Out:
# Text(0.5, 0.98, 'Noise 5 %')
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
